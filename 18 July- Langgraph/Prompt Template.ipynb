# %%
#pip install -U "langchain[google-genai]"
# Out:
# Requirement already satisfied: langchain[google-genai] in c:\users\prati\anaconda3\lib\site-packages (1.3.14)
# Requirement already satisfied: langchain-core<2.0.0,>=1.4.9 in c:\users\prati\anaconda3\lib\site-packages (from langchain[google-genai]) (1.5.0)
# Requirement already satisfied: langgraph<1.3.0,>=1.2.5 in c:\users\prati\anaconda3\lib\site-packages (from langchain[google-genai]) (1.2.9)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\prati\anaconda3\lib\site-packages (from langchain[google-genai]) (2.13.4)
# Requirement already satisfied: langchain-google-genai in c:\users\prati\anaconda3\lib\site-packages (from langchain[google-genai]) (4.2.7)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\prati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.17 in c:\users\prati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (0.0.18)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in c:\users\prati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (0.10.6)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\prati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (25.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\prati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\prati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (9.1.2)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\prati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\prati\anaconda3\lib\site-packages (from langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (0.17.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\prati\anaconda3\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (3.0.0)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=4.1.0 in c:\users\prati\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (4.1.1)
# Requirement already satisfied: langgraph-prebuilt<1.2.0,>=1.1.0 in c:\users\prati\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (1.1.0)
# Requirement already satisfied: langgraph-sdk<0.5.0,>=0.4.2 in c:\users\prati\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\prati\anaconda3\lib\site-packages (from langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (3.8.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in c:\users\prati\anaconda3\lib\site-packages (from langgraph-checkpoint<5.0.0,>=4.1.0->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\prati\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in c:\users\prati\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (3.11.9)
# Requirement already satisfied: websockets<16,>=14 in c:\users\prati\anaconda3\lib\site-packages (from langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (15.0.1)
# Requirement already satisfied: anyio>=3.5.0 in c:\users\prati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (4.10.0)
# Requirement already satisfied: distro>=1.7.0 in c:\users\prati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (1.9.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\prati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\prati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\prati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (1.3.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\prati\anaconda3\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (0.24.0)
# Requirement already satisfied: certifi in c:\users\prati\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (2026.5.20)
# Requirement already satisfied: httpcore==1.* in c:\users\prati\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (1.0.9)
# Requirement already satisfied: idna in c:\users\prati\anaconda3\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\prati\anaconda3\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.5.0,>=0.4.2->langgraph<1.3.0,>=1.2.5->langchain[google-genai]) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\prati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.6.0)
# Requirement already satisfied: pydantic-core==2.46.4 in c:\users\prati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\prati\anaconda3\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\prati\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\prati\anaconda3\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.4.9->langchain[google-genai]) (2.5.0)
# Requirement already satisfied: filetype<2.0.0,>=1.2.0 in c:\users\prati\anaconda3\lib\site-packages (from langchain-google-genai->langchain[google-genai]) (1.2.0)
# Requirement already satisfied: google-genai<3.0.0,>=1.65.0 in c:\users\prati\anaconda3\lib\site-packages (from langchain-google-genai->langchain[google-genai]) (2.12.1)
# Requirement already satisfied: google-auth<2.56.0,>=2.48.1 in c:\users\prati\anaconda3\lib\site-packages (from google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (2.55.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\prati\anaconda3\lib\site-packages (from google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: cryptography>=38.0.3 in c:\users\prati\anaconda3\lib\site-packages (from google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (46.0.3)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\prati\anaconda3\lib\site-packages (from cryptography>=38.0.3->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\prati\anaconda3\lib\site-packages (from cffi>=2.0.0->cryptography>=38.0.3->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (2.23)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in c:\users\prati\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<2.56.0,>=2.48.1->google-auth[requests]<2.56.0,>=2.48.1->google-genai<3.0.0,>=1.65.0->langchain-google-genai->langchain[google-genai]) (0.6.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from langchain.chat_models import init_chat_model

os.environ["GOOGLE_API_KEY"] = "GOOGLE_API_KEY"

model = init_chat_model(
    "google_genai:gemini-3.1-flash-lite"
)

# %%
response = model.invoke("about software jobs in 2026 to 2030?")
print(response.text)
# Out:
# Predicting the software industry landscape from 2026 to 2030 requires moving away from the "coding boot camp" era and into a period of **AI-integrated systems architecture.**
#
# By 2026, the initial "gold rush" of Generative AI will have settled into a period of deep integration. Here is what you can expect for software jobs between 2026 and 2030:
#
# ### 1. The Death of the "Pure Coder"
# The market will no longer pay a premium for people who simply translate tickets into code. Because LLMs (like future versions of GPT, Claude, and specialized coding agents) handle boilerplate, syntax, and basic debugging, the "Junior Developer" role as it existed in 2020 is largely dead.
# *   **The Shift:** You must be a **"Software Architect/Engineer"** who understands system design, security, scalability, and business outcomes. You are no longer writing code; you are managing a fleet of AI agents that write the code.
#
# ### 2. High-Demand Roles (2026–2030)
# *   **AI/ML Infrastructure Engineers:** Moving AI from "cool demo" to "production-grade enterprise software" is incredibly difficult. Companies will pay top dollar for engineers who can handle model fine-tuning, retrieval-augmented generation (RAG) pipelines, and LLM orchestration (e.g., LangChain/LlamaIndex on steroids).
# *   **Cybersecurity & AI Governance:** As AI agents gain more autonomy, the attack surface grows exponentially. Roles in **AI Red Teaming** and **AI Security** (ensuring models aren’t "prompt-injected" or leaking proprietary data) will explode.
# *   **Legacy Systems Modernization Specialists:** Most of the world’s banking, healthcare, and infrastructure runs on ancient code (COBOL, older C++, legacy Java). Bridging the gap between 30-year-old monoliths and modern AI-driven cloud architectures will be a massive industry.
# *   **Data Engineers (The Foundation):** AI is useless without proprietary, clean data. Engineers who can structure, clean, and pipe data into LLMs will be more valuable than the people building the models themselves.
#
# ### 3. The "Product-Minded" Engineer
# The 2026–2030 period will favor developers who act like Product Managers. If you can bridge the gap between "what the customer needs" and "what the software can do," you become indispensable.
# *   **Soft skills will matter more than ever.** In an era where AI handles the technical execution, the human value proposition shifts to **empathy, communication, requirements gathering, and strategic thinking.**
#
# ### 4. The Market Climate: "Quality over Quantity"
# The era of "growth at all costs" (2010–2022) is over.
# *   **Efficiency:** Companies are prioritizing profitability. They aren't hiring 50 junior devs to build a feature; they are hiring 5 senior engineers who can use AI to do the work of 20 people.
# *   **Global Competition:** Remote work is now truly global. You aren't just competing with the person in your city; you are competing with developers worldwide who are also using the same AI tools. To stay ahead, you must demonstrate **domain expertise**—be the person who understands the *finance* industry, or the *healthcare* industry, not just the *coding* industry.
#
# ### 5. What You Should Focus on Now
# If you are planning for a career in this window, stop focusing solely on "learning a new framework" (like Next.js or React) and focus on:
# 1.  **Fundamental Computer Science:** Data structures, algorithms, and networking. These won't change even as AI evolves.
# 2.  **System Design:** Learn how systems communicate (APIs, distributed systems, caching, databases).
# 3.  **AI Orchestration:** Learn how to build applications *using* LLMs. Don't just prompt; build systems that feed data *to* the LLM.
# 4.  **Security-First Coding:** Learn how to build systems that are "secure by default."
#
# ### The Bottom Line
# **Is software engineering still a good career?** Yes, but it is becoming a **Senior-level profession.**
#
# The barrier to entry is higher. You need to be able to do more than "code." You need to be a **problem solver who happens to be fluent in programming languages.** If you are willing to evolve from a "code-writer" to a "system-architect," the salaries and job satisfaction in 2030 will be higher than ever. If you expect to simply translate Jira tickets into syntax, AI will likely automate your role by 2028.

# %%
print(response.content)
# Out:
# [{'type': 'text', 'text': 'Predicting the software industry landscape from 2026 to 2030 requires moving away from the "coding boot camp" era and into a period of **AI-integrated systems architecture.**\n\nBy 2026, the initial "gold rush" of Generative AI will have settled into a period of deep integration. Here is what you can expect for software jobs between 2026 and 2030:\n\n### 1. The Death of the "Pure Coder"\nThe market will no longer pay a premium for people who simply translate tickets into code. Because LLMs (like future versions of GPT, Claude, and specialized coding agents) handle boilerplate, syntax, and basic debugging, the "Junior Developer" role as it existed in 2020 is largely dead.\n*   **The Shift:** You must be a **"Software Architect/Engineer"** who understands system design, security, scalability, and business outcomes. You are no longer writing code; you are managing a fleet of AI agents that write the code.\n\n### 2. High-Demand Roles (2026–2030)\n*   **AI/ML Infrastructure Engineers:** Moving AI from "cool demo" to "production-grade enterprise software" is incredibly difficult. Companies will pay top dollar for engineers who can handle model fine-tuning, retrieval-augmented generation (RAG) pipelines, and LLM orchestration (e.g., LangChain/LlamaIndex on steroids).\n*   **Cybersecurity & AI Governance:** As AI agents gain more autonomy, the attack surface grows exponentially. Roles in **AI Red Teaming** and **AI Security** (ensuring models aren’t "prompt-injected" or leaking proprietary data) will explode.\n*   **Legacy Systems Modernization Specialists:** Most of the world’s banking, healthcare, and infrastructure runs on ancient code (COBOL, older C++, legacy Java). Bridging the gap between 30-year-old monoliths and modern AI-driven cloud architectures will be a massive industry.\n*   **Data Engineers (The Foundation):** AI is useless without proprietary, clean data. Engineers who can structure, clean, and pipe data into LLMs will be more valuable than the people building the models themselves.\n\n### 3. The "Product-Minded" Engineer\nThe 2026–2030 period will favor developers who act like Product Managers. If you can bridge the gap between "what the customer needs" and "what the software can do," you become indispensable.\n*   **Soft skills will matter more than ever.** In an era where AI handles the technical execution, the human value proposition shifts to **empathy, communication, requirements gathering, and strategic thinking.**\n\n### 4. The Market Climate: "Quality over Quantity"\nThe era of "growth at all costs" (2010–2022) is over.\n*   **Efficiency:** Companies are prioritizing profitability. They aren\'t hiring 50 junior devs to build a feature; they are hiring 5 senior engineers who can use AI to do the work of 20 people.\n*   **Global Competition:** Remote work is now truly global. You aren\'t just competing with the person in your city; you are competing with developers worldwide who are also using the same AI tools. To stay ahead, you must demonstrate **domain expertise**—be the person who understands the *finance* industry, or the *healthcare* industry, not just the *coding* industry.\n\n### 5. What You Should Focus on Now\nIf you are planning for a career in this window, stop focusing solely on "learning a new framework" (like Next.js or React) and focus on:\n1.  **Fundamental Computer Science:** Data structures, algorithms, and networking. These won\'t change even as AI evolves.\n2.  **System Design:** Learn how systems communicate (APIs, distributed systems, caching, databases).\n3.  **AI Orchestration:** Learn how to build applications *using* LLMs. Don\'t just prompt; build systems that feed data *to* the LLM.\n4.  **Security-First Coding:** Learn how to build systems that are "secure by default."\n\n### The Bottom Line\n**Is software engineering still a good career?** Yes, but it is becoming a **Senior-level profession.** \n\nThe barrier to entry is higher. You need to be able to d ...
