# %% [markdown]
# # Langugae Translation

# %%
import os
from langchain_google_genai import ChatGoogleGenerativeAI

os.environ["GOOGLE_API_KEY"] = "GOOGLE_API_KEY"

model = ChatGoogleGenerativeAI(
    model="gemini-3.1-flash-lite",
    temperature=0
)

# %%
from langchain_core.messages import HumanMessage, SystemMessage

messages = [
    SystemMessage("You are a helpful assistant that translates English to Marathi."),
    HumanMessage("Translate this sentence from English to Marathi: 'I love programming.'"),
]
model.invoke(messages)
# Out:
# AIMessage(content=[{'type': 'text', 'text': "'I love programming' चे मराठीत भाषांतर खालीलप्रमाणे आहे:\n\n**मला प्रोग्रामिंग करायला आवडते.**", 'extras': {'signature': 'EjQKMgERTTIPdbcp0RKENly0v8BKE9v8jz/oxOh+RZ2G94JFxGGceyThhfK5wdAOPVAy0PMu'}}], additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.1-flash-lite', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f8abf-7103-7162-8391-64dd700b51b8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 25, 'output_tokens': 25, 'total_tokens': 50, 'input_token_details': {'cache_read': 0}})

# %%
response1 = model.invoke(messages)

# %%
print(response1.text)
# Out:
# 'I love programming' चे मराठीत भाषांतर खालीलप्रमाणे आहे:
#
# **मला प्रोग्रामिंग करायला आवडते.**
