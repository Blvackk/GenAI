# %%
! pip install -q -U google-generativeai

# %%
import os
os.environ['GEMINI_API_KEY'] = 'EMINI_API_KEY'

# %%
import google.generativeai as genai
genai.configure(api_key = os.environ['GEMINI_API_KEY'])
# Out:
# C:\Users\prati\AppData\Local\Temp\ipykernel_11280\1295831231.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %%
model = genai.GenerativeModel('models/gemini-3-flash-preview')

# %%
response =  model.generate_content("tabular format of the answer difference between ai vs gen ai vs llm ")
print(response.text)
# Out:
# Here is the comparison between **AI**, **Generative AI**, and **LLMs** in a tabular format, followed by a brief explanation of how they relate to one another.
#
# ### Comparison Table: AI vs. GenAI vs. LLM
#
# | Feature | Artificial Intelligence (AI) | Generative AI (GenAI) | Large Language Models (LLM) |
# | :--- | :--- | :--- | :--- |
# | **Definition** | The broad field of creating systems capable of performing tasks that normally require human intelligence. | A subfield of AI focused on **creating new content** based on patterns learned from existing data. | A specific type of GenAI trained on massive datasets to understand and generate **human-like text**. |
# | **Scope** | **The Umbrella:** Includes everything from simple rules to complex neural networks. | **The Creative Branch:** A subset of AI and Machine Learning. | **The Text Specialist:** A subset of Generative AI. |
# ...

# %%
import pathlib
import textwrap

import google.generativeai as genai
from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('.', ' *')
    return Markdown(textwrap.indent(text, '>', predicate=lambda _: True))

# %%
for m in genai.list_models():
    if 'generateContent' in m.supported_generation_methods:
        print(m.name)
# Out:
# models/gemini-2.5-flash
# models/gemini-2.5-pro
# models/gemini-2.0-flash
# models/gemini-2.0-flash-001
# models/gemini-2.0-flash-lite-001
# models/gemini-2.0-flash-lite
# models/gemini-2.5-flash-preview-tts
# models/gemini-2.5-pro-preview-tts
# models/gemma-4-26b-a4b-it
# models/gemma-4-31b-it
# models/gemini-flash-latest
# models/gemini-flash-lite-latest
# models/gemini-pro-latest
# models/gemini-2.5-flash-lite
# models/gemini-2.5-flash-image
# models/gemini-3-pro-preview
# models/gemini-3-flash-preview
# models/gemini-3.1-pro-preview
# models/gemini-3.1-pro-preview-customtools
# models/gemini-3.1-flash-lite-preview
# models/gemini-3.1-flash-lite
# models/gemini-3-pro-image-preview
# models/gemini-3-pro-image
# models/nano-banana-pro-preview
# models/gemini-3.1-flash-image-preview
# models/gemini-3.1-flash-image
# models/gemini-3.1-flash-lite-image
# models/gemini-3.5-flash
# models/gemini-3.5-flash-lite
# models/gemini-omni-flash-preview
# models/gemini-3.6-flash
# ...

# %%
model = genai.GenerativeModel('models/gemini-3-flash-preview')

# %%
# %%time
response = model.generate_content("Create a table for summarize to a kid about data science vs Machine Learning")
# Out:
# CPU times: total: 359 ms
# Wall time: 3min 36s

# %%
to_markdown(response.text)
# Out:
# >Here is a simple table to help a kid understand the difference between **Data Science** and **Machine Learning** using the idea of a **Detective** and a **Robot ***
# >
# >### The Quick Comparison
# >
# >| Feature | Data Science (The Detective) | Machine Learning (The Robot Brain) |
# >| :--- | :--- | :--- |
# >| **What is it?** | Looking at a giant pile of clues to tell a story or solve a big problem * | Teaching a computer how to learn from examples so it can do things on its own * |
# >| **The Main Goal** | To find "Why" something happened and what we should do next * | To make a "Prediction" (a smart guess) about something new * |
# >| **How it works** | Uses math, charts, and smart thinking to explain the world * | Uses "Training" (like practice) so the computer gets smarter over time * |
# ...

# %% [markdown]
# # Text Model we built using different gemini models & Latest Models

# %%
import PIL.Image

img = PIL.Image.open(r"C:\Users\prati\Downloads\AAdhar  .jpeg")
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=733x1600>

# %%
model = genai.GenerativeModel('models/gemini-3-flash-preview')

# %%
import pathlib
import textwrap
import google.generativeai as genaai

from IPython.display import display
from IPython.display import Markdown

def to_markdown(text):
    text = text.replace('.', ' *')
    return Markdown(textwrap.indent(text, '>', predicate=lambda _: True))

# %%
response = model.generate_content(img)
to_markdown(response.text)
# Out:
# >The image shows an Indian Aadhaar card letter with the following details:
# >
# >*   **Enrollment No:** 1067/11510/01210
# >*   **Name:** Pratik Shrinivas Lagishetty (प्रतिक श्रीनिवास लगीशेट्टी)
# >*   **Address:** 209/3, Balaji Nagar, Bhandari compound Road, Near Natraj Bar, Bhiwandi, Vidyashram Bhiwandi, Thane, Maharashtra - 421305
# >*   **Phone Number:** 8983730001
# >*   **Aadhaar Number:** 4437 4162 9346
# >*   **Year of Birth:** 2004
# >*   **Gender:** Male (पुरुष)
# >*   **Date on document:** 08/04/2013
# >
# >**Important Security Warning:** This image contains sensitive personal information, including a full name, address, phone number, and national identification number * Sharing such information publicly online can lead to identity theft, privacy breaches, and other security risks * It is strongly recommended to protect this information and avoid sharing images of official ID documents on public platforms *

# %%
model = genai.GenerativeModel('models/gemini-3-flash-preview')
chat = model.start_chat(history=[])
chat
# Out:
# ChatSession(
#     model=genai.GenerativeModel(
#         model_name='models/gemini-3-flash-preview',
#         generation_config={},
#         safety_settings={},
#         tools=None,
#         system_instruction=None,
#         cached_content=None
#     ),
#     history=[]
# )

# %%
chat.history
# Out:
# []

# %%
for message in chat.history:
    display(to_markdown(f'**{message.role}**:{message.parts[0].text}'))

# %%
model.count_tokens("What is the meaning of life ?")
# Out:
# total_tokens: 7
